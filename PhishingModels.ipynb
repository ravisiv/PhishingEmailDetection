# %%
#Any imports

# %%
def run_randomforestclassifier(df):
    return None

# %%
def run_naivebaiyes(df):
    return None

# %%
def run_kmeans(df):
    return None

# %%
def run_xgboost(df):
    return None

# %%
def run_faiss(df):
    return None

# %%
def run_BERT(df):
    return None

# %%
def run_KERAS(df):
    return None
